# %% [markdown]
# <a href="https://colab.research.google.com/github/junxnone/examples/blob/master/keras/image-segmentation-keras/predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/divamgupta/image-segmentation-keras.git
# Out:
# Cloning into 'image-segmentation-keras'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 538 (delta 61), reused 37 (delta 20), pack-reused 433
# Receiving objects: 100% (538/538), 3.13 MiB | 8.64 MiB/s, done.
# Resolving deltas: 100% (298/298), done.

# %%
# !pip -q install git+https://github.com/divamgupta/image-segmentation-keras.git

# %%
from keras_segmentation.pretrained import pspnet_50_ADE_20K , pspnet_101_cityscapes, pspnet_101_voc12
import cv2
import matplotlib.pyplot as plt

# %%
model = pspnet_50_ADE_20K() # load the pretrained model trained on ADE20k dataset

# %%
# %ls image-segmentation-keras/sample_images/
# Out:
# 1_input.jpg  1_output.png  2_input.jpg  2_output.png  3_input.jpg  3_output.png

# %%
input_img = "image-segmentation-keras/sample_images/3_input.jpg"
out = model.predict_segmentation(
    inp= input_img,
    out_fname="out.png"
)

# %%
org_img = cv2.imread(input_img)
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(org_img)
oimg = cv2.imread('./out.png')
plt.subplot(1,2,2)
plt.imshow(oimg)

# %%
model = pspnet_101_cityscapes() # load the pretrained model trained on Cityscapes dataset
input_img = "image-segmentation-keras/sample_images/3_input.jpg"
out = model.predict_segmentation(
    inp= input_img,
    out_fname="out.png"
)
org_img = cv2.imread(input_img)
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(org_img)
oimg = cv2.imread('./out.png')
plt.subplot(1,2,2)
plt.imshow(oimg)
