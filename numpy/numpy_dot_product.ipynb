# %% [markdown]
# <a href="https://colab.research.google.com/github/junxnone/examples/blob/master/numpy/numpy_dot_product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.array([[1,2],
                 [3,4]])
b = np.array([[5,6],
                 [7,8]])

# %% [markdown]
# # 点乘 - 点积
# ---
# - 向量*矩阵
# ![image.png](data:image/png;base64,...)
#
# ---
# - 矩阵
#
# ![image.png](data:image/png;base64,...)

# %%
a*b
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %% [markdown]
# # 矩阵乘法
# a.dot(b) == np.dot(a, b)
#
# ---
# ![image.png](data:image/png;base64,...)

# %%
a.dot(b)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
np.dot(a, b)
# Out:
# array([[19, 22],
#        [43, 50]])
