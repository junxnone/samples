# %% [markdown]
# <a href="https://colab.research.google.com/github/junxnone/examples/blob/master/pytorch/pytorch_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch  
from torchvision.datasets import *
import matplotlib.pyplot as plt

# %%
def plot_ds(dataset, N=8):
  i = 1
  plt.figure(figsize=(20, 5 * N//4 + 1))
  for data in dataset:
      inputs, labels = data
      plt.subplot(N//4 + 1,4,i)
      plt.imshow(inputs)
      i += 1
      if i > N:
          break

# %%
CelebA_DS = CelebA('./', download=True)
plot_ds(CelebA_DS)

# %%
CIFAR10_DS = CIFAR10('./', download=True)
plot_ds(CIFAR10_DS)
# Out:
# Files already downloaded and verified

# %%
CIFAR100_DS = CIFAR100('./', download=True)
plot_ds(CIFAR100_DS)
# Out:
# ...
# Extracting ./cifar-100-python.tar.gz to ./

# %% [markdown]
# **split**
# - byclass
# - bymerge
# - balanced
# - letters
# - digits
# - mnist

# %%
EMNIST_DS = EMNIST('./', split='byclass', download=True)
plot_ds(EMNIST_DS)
# Out:
# ...
# Extracting ./EMNIST/raw/emnist.zip to ./EMNIST/raw
# Processing byclass
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Processing bymerge
# Processing balanced
# Processing letters
# Processing digits
# Processing mnist
# Done!

# %%
FashionMNIST_DS = FashionMNIST('./', download=True)
plot_ds(FashionMNIST_DS)
# Out:
# ...
# Extracting ./FashionMNIST/raw/train-images-idx3-ubyte.gz to ./FashionMNIST/raw
# ...
# Extracting ./FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./FashionMNIST/raw
# ...
# Extracting ./FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./FashionMNIST/raw
# ...
# Extracting ./FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./FashionMNIST/raw
# Processing...
# Done!

# %%
KMNIST_DS = KMNIST('./', download=True)
plot_ds(KMNIST_DS)
# Out:
# ...
# Extracting ./KMNIST/raw/train-images-idx3-ubyte.gz to ./KMNIST/raw
# ...
# Extracting ./KMNIST/raw/train-labels-idx1-ubyte.gz to ./KMNIST/raw
# ...
# Extracting ./KMNIST/raw/t10k-images-idx3-ubyte.gz to ./KMNIST/raw
# ...
# Extracting ./KMNIST/raw/t10k-labels-idx1-ubyte.gz to ./KMNIST/raw
# Processing...
# Done!

# %%
MNIST_DS = MNIST('./', download=True)
plot_ds(MNIST_DS)
# Out:
# ...
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
# ...
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
# ...
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
# ...
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
# Processing...
# Done!

# %%
Omniglot_DS = Omniglot('./', download=True)
plot_ds(Omniglot_DS)
# Out:
# ...
# Extracting ./omniglot-py/images_background.zip to ./omniglot-py

# %% [markdown]
# **name**
# - notredame_harris
# - yosemite_harris
# - liberty_harris
# - notredame
# - yosemite
# - liberty

# %%
PhotoTour_DS = PhotoTour('./', name = 'notredame_harris', download=True)
# plot_ds(PhotoTour_DS)

# %%
Places365_DS = Places365('./', split = 'val', download=True)
plot_ds(Places365_DS)
# Out:
# ...
# Extracting ./filelist_places365-standard.tar to ./
#
# ...
# Extracting ./val_large.tar to ./

# %%
QMNIST_DS = QMNIST('./', download=True)
plot_ds(QMNIST_DS)
# Out:
# ...
# Processing...

# %%
SBD_DS = SBDataset('./', download=True)
plot_ds(SBD_DS)

# %%
SBU_DS = SBU('./', download=True)
plot_ds(SBU_DS)

# %%
STL10_DS = STL10('./', download=True)
plot_ds(STL10_DS)
# Out:
# ...
# Extracting ./stl10_binary.tar.gz to ./

# %%
SVHN_DS = SVHN('./', download=True)
plot_ds(SVHN_DS)

# %%
USPS_DS = USPS('./', download=True)
plot_ds(USPS_DS)

# %%
VOCSegmentation_DS = VOCSegmentation('./vocseg/', image_set='val', download=True)
plot_ds(VOCSegmentation_DS)
# Out:
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-65-6e2f084f7d7e> in <module>()
# ----> 1 VOCSegmentation_DS = VOCSegmentation('./vocseg/', image_set='val', download=True)
#       2 plot_ds(VOCSegmentation_DS)
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/voc.py in __init__(self, root, year, image_set, download, transform, target_transform, transforms)
#      99
#     100         if download:
# --> 101             download_extract(self.url, self.root, self.filename, self.md5)
#     102
#     103         if not os.path.isdir(voc_root):
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/voc.py in download_extract(url, root, filename, md5)
#     243
#     244 def download_extract(url: str, root: str, filename: str, md5: str) -> None:
# --> 245     download_url(url, root, filename, md5)
# ...

# %%
VOCDetection_DS = VOCDetection('./',  image_set='val', download=True)
plot_ds(VOCDetection_DS)
# Out:
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-64-d69665cc0139> in <module>()
# ----> 1 VOCDetection_DS = VOCDetection('./',  image_set='val', download=True)
#       2 plot_ds(VOCDetection_DS)
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/voc.py in __init__(self, root, year, image_set, download, transform, target_transform, transforms)
#     183
#     184         if download:
# --> 185             download_extract(self.url, self.root, self.filename, self.md5)
#     186
#     187         if not os.path.isdir(voc_root):
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/voc.py in download_extract(url, root, filename, md5)
#     243
#     244 def download_extract(url: str, root: str, filename: str, md5: str) -> None:
# --> 245     download_url(url, root, filename, md5)
# ...
